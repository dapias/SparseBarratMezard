# %%
using Plots
pyplot()
# Out:
# Plots.PyPlotBackend()

# %%
using LaTeXStrings

# %%
using JLD

# %%
cav1 = load("rho_gaussian.jld")
# Out:
# Dict{String,Any} with 5 entries:
#   "c"       => 5
#   "N"       => 1000
#   "epsilon" => 0.0+0.005im
#   "lambdas" => -4.1:0.1:4.1
#   "rho"     => [0.00011683, 0.000126247, 0.000131723, 0.000141683, 0.00015371, …

# %%
rho_cav = cav1["rho"]
l_grid = cav1["lambdas"];
epsilon = cav1["epsilon"];

# %%
plot(l_grid, rho_cav,  ls = :dash, label = L"\epsilon"*"= 0.005im")

# %%
numerics = load("emp_gaussian.jld")
# Out:
# Dict{String,Any} with 4 entries:
#   "c"           => 5
#   "ensemble"    => 1000
#   "eigenvalues" => [-2.77303, -2.68625, -2.57025, -2.4531, -2.40924, -2.32259, …
#   "N"           => 1000

# %%
rho_emp = numerics["eigenvalues"];

# %%
stephist!(rho_emp, nbins = 100, normed = true, label = "Numerics", ylim = (0.,0.8))
